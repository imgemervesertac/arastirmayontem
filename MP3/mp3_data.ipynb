# %% [markdown]
# MP3 Ödevi:Kahve Tüketim Miktarının Günlük Duygu Durumu Üzerindeki Etkisi

# %% [markdown]
# Kahve tüketiminin günlük duygu durumuna etkisini araştırdığımız bu çalışmada, veri toplama yöntemi olarak açık veri setlerinden faydalandık.Bu veri setine Kaggle üzerinden ulaştık.

# %%
import pandas as pd 
df = pd.read_csv("data_mp3.csv", encoding="cp1254",sep=";")
df.head()
# Out:
#    Kafein miktarı (mg) Duygu durumları
# 0                 74.0        Stressed
# 1                164.0         Neutral
# 2                 88.0           Happy
# 3                121.0        Stressed
# 4                110.0           Happy
